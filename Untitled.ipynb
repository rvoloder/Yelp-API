# %%
import json
with open('/Users/rijavoloder/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
from yelpapi import YelpAPI
import pandas as pd

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
tacos = yelp_api.search_query(location='San Diego, CA',
                                       term='Tacos')
type(tacos)
tacos.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
tacos = pd.DataFrame(tacos['businesses'])
tacos.head(2)
# Out:
#                        id                        alias               name  \
# 0  dBtZR2CB8PVxndyF6K2wAQ      the-taco-stand-la-jolla     The Taco Stand
# 1  0qMYBzJUjXa8_MIm5mkjKA  el-viejón-seafood-san-diego  El Viejón Seafood
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/iovVv7...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/GcliBY...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-taco-stand-la-jol...          4102
# 1  https://www.yelp.com/biz/el-viej%C3%B3n-seafoo...           161
#
#                                           categories  rating  \
# 0  [{'alias': 'foodstands', 'title': 'Food Stands...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     5.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 32.8393664861151, 'longitude': -1...  [delivery, pickup]
# ...

# %%
tacos['total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
tacos2 = yelp_api.search_query(location='San Diego, CA',
                                       term='tacos',
                               offset = 20)

# %%
tacos2 = pd.DataFrame(tacos2['businesses'])
tacos2.head(2)
# Out:
#                        id                                      alias  \
# 0  ByT2w8djGeGYrVG1eBnb9w           mariscos-mi-gusto-es-san-diego-2
# 1  bCDi6bD9bCISqFZ3OyDbOg  vallarta-express-mexican-eatery-san-diego
#
#                               name  \
# 0             Mariscos Mi Gusto Es
# 1  Vallarta Express Mexican Eatery
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/Q9hWpu...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/hfFoSP...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mariscos-mi-gusto-es-...           323
# 1  https://www.yelp.com/biz/vallarta-express-mexi...          1486
#
#                                           categories  rating  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     5.0
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
#
# ...

# %%
all_tacos = pd.concat([tacos, tacos2],
                      ignore_index=True)
display(all_tacos.head(3), all_tacos.tail(3))
# Out:
#                        id                                      alias  \
# 0  ByT2w8djGeGYrVG1eBnb9w           mariscos-mi-gusto-es-san-diego-2
# 1  bCDi6bD9bCISqFZ3OyDbOg  vallarta-express-mexican-eatery-san-diego
# 2  aexwoC8z_5tvEOkeEM1nXQ                    birria-el-rey-san-diego
#
#                               name  \
# 0             Mariscos Mi Gusto Es
# 1  Vallarta Express Mexican Eatery
# 2                    Birria El Rey
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/Q9hWpu...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/hfFoSP...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/hqcHYJ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mariscos-mi-gusto-es-...           323
# 1  https://www.yelp.com/biz/vallarta-express-mexi...          1486
# 2  https://www.yelp.com/biz/birria-el-rey-san-die...           132
#
# ...

# %%
all_tacos.to_json(orient='records')
# Out:
# '[{"id":"ByT2w8djGeGYrVG1eBnb9w","alias":"mariscos-mi-gusto-es-san-diego-2","name":"Mariscos Mi Gusto Es","image_url":"https:\\/\\/s3-media2.fl.yelpcdn.com\\/bphoto\\/Q9hWpuS1SGZnE33Tp2_Wqw\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/mariscos-mi-gusto-es-san-diego-2?adjust_creative=Ku8tqLqhONRsEhQcVF486g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ku8tqLqhONRsEhQcVF486g","review_count":323,"categories":[{"alias":"mexican","title":"Mexican"},{"alias":"foodtrucks","title":"Food Trucks"},{"alias":"seafood","title":"Seafood"}],"rating":5.0,"coordinates":{"latitude":32.729069,"longitude":-117.098941},"transactions":[],"price":"$","location":{"address1":"4425 Home Ave","address2":null,"address3":null,"city":"San Diego","zip_code":"92105","country":"US","state":"CA","display_address":["4425 Home Ave","San Diego, CA 92105"]},"phone":"+16192745924","display_phone":"(619) 274-5924","distance":8561.0128791869},{"id":"bCDi6bD9bCISqFZ3OyDbOg","alia
# ...
